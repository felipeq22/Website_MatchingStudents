# %% [markdown]
# test

# %%
#!pip install pulp
#!pip install seaborn

# %%
from algorithm_ILP_SQL import load_csvs_to_db, load_data_first, optimize_course_matching, load_data_second, check_time_conflict, optimize_lab_matching

# %%
load_data_first()
# Out:
# (    course_id                   course_name  mandatory  program_id  has_lab
#  0           1              Machine Learning          1           1        1
#  1           2  Data structure and algorithm          1           1        1
#  2           3                 Deep learning          0           1        1
#  3           4   Natural Language Processing          0           1        1
#  4           5            Law and Governance          0           1        0
#  5           6                  Statistics 2          1           2        1
#  6           7                   Economics 2          1           2        1
#  7           8                 Global Ethics          0           2        0
#  8           9         Development Economics          0           2        1
#  9          10            Law and Governance          0           2        0
#  10         11                  Statistics 2          1           3        1
# ...

# %%
optimize_course_matching()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/dmnkallen/miniconda3/envs/dsa/lib/python3.11/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/h2/cjz3psl56751427w176wxbqh0000gn/T/85ded00e1dc64619b2ef135eee923326-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/h2/cjz3psl56751427w176wxbqh0000gn/T/85ded00e1dc64619b2ef135eee923326-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 35 COLUMNS
# At line 308 RHS
# At line 339 BOUNDS
# At line 417 ENDATA
# Problem MODEL has 30 rows, 77 columns and 98 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 133 - 0.00 seconds
# Cgl0004I processed model has 5 rows, 15 columns (15 integer (15 of which binary)) and 15 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# ...

# %%
load_data_second()
# Out:
# (    student_id   student_name course_type  course_id  \
#  0         2501   Elena Murray   Mandatory          1
#  1         2501   Elena Murray   Mandatory          2
#  2         2501   Elena Murray    Elective          3
#  3         2501   Elena Murray    Elective          4
#  4         2502  Dominik Allen   Mandatory         11
#  5         2502  Dominik Allen   Mandatory         12
#  6         2502  Dominik Allen    Elective         14
#  7         2502  Dominik Allen    Elective         15
#  8         2503   Corbin Cerny   Mandatory          6
#  9         2503   Corbin Cerny   Mandatory          7
#  10        2503   Corbin Cerny    Elective          8
#  11        2503   Corbin Cerny    Elective          9
#  12        2504  Juan Quinones   Mandatory          1
#  13        2504  Juan Quinones   Mandatory          2
#  14        2504  Juan Quinones    Elective          4
#  15        2504  Juan Quinones    Elective          5
# ...

# %%
optimize_lab_matching()
# Out:
# Initial Data Analysis:
# Total students in course matching: 7
# Total lab time entries: 18
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/dmnkallen/miniconda3/envs/dsa/lib/python3.11/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/h2/cjz3psl56751427w176wxbqh0000gn/T/c50ae0629cd94965b253987be9933e1d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/h2/cjz3psl56751427w176wxbqh0000gn/T/c50ae0629cd94965b253987be9933e1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 24 COLUMNS
# At line 172 RHS
# At line 192 BOUNDS
# At line 231 ENDATA
# Problem MODEL has 19 rows, 38 columns and 38 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 153 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# ...
