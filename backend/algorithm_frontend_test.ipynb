# %%
#!pip install pulp
#!pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %%
from algorithm_final import optimize_course_matching, load_data_first, load_data_second, optimize_lab_matching

# %%
load_data_first()
# Out:
# (    course_id                   course_name  mandatory  program_id  has_lab
#  0           1              Machine Learning          1           1        1
#  1           2  Data structure and algorithm          1           1        1
#  2           3                 Deep learning          0           1        1
#  3           4   Natural Language Processing          0           1        1
#  4           5            Law and Governance          0           1        0
#  5           6                  Statistics 2          1           2        1
#  6           7                   Economics 2          1           2        1
#  7           8                 Global Ethics          0           2        0
#  8           9         Development Economics          0           2        1
#  9          10            Law and Governance          0           2        0
#  10         11                  Statistics 2          1           3        1
# ...

# %%
optimize_course_matching()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/felipe_q/Desktop/AI_models/COMPUTER_SCIENCE/dsavenv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/_m/yzl8twvn45zbf_rk8q3h5wl80000gn/T/a78de509e3e44330b9075d5c06af2164-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/_m/yzl8twvn45zbf_rk8q3h5wl80000gn/T/a78de509e3e44330b9075d5c06af2164-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 35 COLUMNS
# At line 308 RHS
# At line 339 BOUNDS
# At line 417 ENDATA
# Problem MODEL has 30 rows, 77 columns and 98 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 133 - 0.00 seconds
# Cgl0004I processed model has 5 rows, 15 columns (15 integer (15 of which binary)) and 15 elements
# Cutoff increment increased from 1e-05 to 0.9999
# ...

# %%
optimize_lab_matching()
# Out:
# Initial Data Analysis:
# Total students in course matching: 7
# Total lab time entries: 18
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/felipe_q/Desktop/AI_models/COMPUTER_SCIENCE/dsavenv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/_m/yzl8twvn45zbf_rk8q3h5wl80000gn/T/8c1f0a72982945359c7a8417d3aa7920-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/_m/yzl8twvn45zbf_rk8q3h5wl80000gn/T/8c1f0a72982945359c7a8417d3aa7920-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 24 COLUMNS
# At line 172 RHS
# At line 192 BOUNDS
# At line 231 ENDATA
# Problem MODEL has 19 rows, 38 columns and 38 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 153 - 0.00 seconds
# ...
